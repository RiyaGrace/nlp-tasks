# %% [markdown]
# NLP TASKS - PART 2 - 19MCB0028

# %% [markdown]
# # LAB 4

# %%
import nltk

# %%
grammar="NP: {<DT>?<JJ>*<NN>}"

# %%
cp=nltk.RegexpParser(grammar)

# %%
text = nltk.word_tokenize("I first got to know X in the course of Database Management Systems, CSE-2004")
nltk.pos_tag(text)
# Out:
# [('I', 'PRP'),
#  ('first', 'RB'),
#  ('got', 'VBD'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('X', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('Database', 'NNP'),
#  ('Management', 'NNP'),
#  ('Systems', 'NNPS'),
#  (',', ','),
#  ('CSE-2004', 'NNP')]

# %%
result=cp.parse(nltk.pos_tag(text))

# %%
print(result)
# Out:
# (S
#   I/PRP
#   first/RB
#   got/VBD
#   to/TO
#   know/VB
#   X/NNP
#   in/IN
#   (NP the/DT course/NN)
#   of/IN
#   Database/NNP
#   Management/NNP
#   Systems/NNPS
#   ,/,
#   CSE-2004/NNP)

# %%
result.draw()

# %%
import nltk
text2 = open("LSamp1.txt")
textdata = text2.read()
sentences = nltk.sent_tokenize(textdata)
grammar = "NP : {<DT>?<JJ>*<NN>}"
cp = nltk.RegexpParser(grammar)
for i in sentences :
  words = nltk.word_tokenize(i)
  tagged = nltk.pos_tag(words)
  chunked = cp.parse(tagged)
  print(chunked)
# Out:
# (S
#   TO/TO
#   WHOMSOEVER/VB
#   IT/NNP
#   MAY/NNP
#   CONCERN/NNP
#   I/PRP
#   am/VBP
#   pleased/JJ
#   to/TO
#   recommend/VB
#   MrXX/NNP
#   for/IN
#   an/DT
#   MS/NNP
#   in/IN
#   Computer/NNP
#   Science/NNP
#   at/IN
#   your/PRP$
#   (NP esteemed/JJ university/NN)
#   ./.)
# (S
#   I/PRP
#   have/VBP
#   known/VBN
#   him/PRP
#   since/IN
#   his/PRP$
#   (NP second/JJ year/NN)
#   ./.)
# (S
#   He/PRP
#   was/VBD
#   my/PRP$
#   (NP student/NN)
#   in/IN
#   the/DT
#   3rd/CD
#   (NP semester/NN)
#   (/(
#   2nd/CD
#   (NP year/NN)
#   )/)
#   ,/,
#   where/WRB
#   I/PRP
#   taught/VBD
#   him/PRP
#   (NP the/DT course/NN)
#   of/IN
#   Database/NNP
#   Management/NNP
#   Systems/NNPS
#   ./.)
# (S
#   I/PRP
#   first/RB
#   got/VBD
#   to/TO
#   know/VB
#   X/NNP
#   in/IN
#   (NP the/DT course/NN)
#   of/IN
#   Database/NNP
#   Management/NNP
#   Systems/NNPS
#   ,/,
#   CSE-2004/NNP
#   ./.)
# (S
#   In/IN
#   (NP the/DT first/JJ week/NN)
#   of/IN
# ...

# %%
chunked.draw()

# %%
#importing text from 'Cinderalla' 
import spacy
nlp = spacy.load('en_core_web_sm')
from urllib import request
url = "https://www.cs.cmu.edu/~spok/grimmtmp/016.txt"
response = request.urlopen(url)
rawtext = response.read().decode('utf8')
type(rawtext)
# Out:
# str

# %%
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

# %%
import re
remove_emojis(rawtext)
# Out:
# "\tCinderella\nThe wife of a rich man fell sick, and as she felt that her end\nwas drawing near, she called her only daughter to her bedside and\nsaid, dear child, be good and pious, and then the\ngood God will always protect you, and I will look down on you\nfrom heaven and be near you.  Thereupon she closed her eyes and\ndeparted.  Every day the maiden went out to her mother's grave,\nand wept, and she remained pious and good.  When winter came\nthe snow spread a white sheet over the grave, and by the time the\nspring sun had drawn it off again, the man had taken another wife.\nThe woman had brought with her into the house two daughters,\nwho were beautiful and fair of face, but vile and black of heart.\nNow began a bad time for the poor step-child.  Is the stupid goose\nto sit in the parlor with us, they said.  He who wants to eat bread\nmust earn it.  Out with the kitchen-wench.  They took her pretty\nclothes away from her, put an old grey bedgown on her, and gave\nher wooden sho
# ...

# %%
#Tokenize
doc = nlp(rawtext)
token_list = []
for token in doc :
    token_list.append(token.text)
print(token_list)
# Out:
# ['\t', 'Cinderella', '\n', 'The', 'wife', 'of', 'a', 'rich', 'man', 'fell', 'sick', ',', 'and', 'as', 'she', 'felt', 'that', 'her', 'end', '\n', 'was', 'drawing', 'near', ',', 'she', 'called', 'her', 'only', 'daughter', 'to', 'her', 'bedside', 'and', '\n', 'said', ',', 'dear', 'child', ',', 'be', 'good', 'and', 'pious', ',', 'and', 'then', 'the', '\n', 'good', 'God', 'will', 'always', 'protect', 'you', ',', 'and', 'I', 'will', 'look', 'down', 'on', 'you', '\n', 'from', 'heaven', 'and', 'be', 'near', 'you', '.', ' ', 'Thereupon', 'she', 'closed', 'her', 'eyes', 'and', '\n', 'departed', '.', ' ', 'Every', 'day', 'the', 'maiden', 'went', 'out', 'to', 'her', 'mother', "'s", 'grave', ',', '\n', 'and', 'wept', ',', 'and', 'she', 'remained', 'pious', 'and', 'good', '.', ' ', 'When', 'winter', 'came', '\n', 'the', 'snow', 'spread', 'a', 'white', 'sheet', 'over', 'the', 'grave', ',', 'and', 'by', 'the', 'time', 'the', '\n', 'spring', 'sun', 'had', 'drawn', 'it', 'off', 'again', ',', 'the', 'm
# ...

# %%
#POS
for word in doc:
    print(word.text,word.pos_)
# Out:
# 	 SPACE
# Cinderella NOUN
#
#  SPACE
# The DET
# wife NOUN
# of ADP
# a DET
# rich ADJ
# man NOUN
# fell VERB
# sick ADJ
# , PUNCT
# and CCONJ
# as SCONJ
# she PRON
# felt VERB
# that SCONJ
# her DET
# end NOUN
#
#  SPACE
# was AUX
# drawing VERB
# near ADV
# , PUNCT
# she PRON
# called VERB
# her DET
# only ADJ
# daughter NOUN
# to ADP
# her DET
# bedside NOUN
# and CCONJ
#
#  SPACE
# said VERB
# , PUNCT
# dear ADJ
# child NOUN
# , PUNCT
# be AUX
# good ADJ
# and CCONJ
# pious ADJ
# , PUNCT
# and CCONJ
# then ADV
# the DET
#
#  SPACE
# good ADJ
# God PROPN
# will VERB
# always ADV
# protect VERB
# you PRON
# , PUNCT
# and CCONJ
# I PRON
# will VERB
# look VERB
# down ADP
# on ADP
# you PRON
#
#  SPACE
# from ADP
# heaven PROPN
# and CCONJ
# be AUX
# near SCONJ
# you PRON
# . PUNCT
#   SPACE
# Thereupon ADV
# she PRON
# closed VERB
# her DET
# eyes NOUN
# and CCONJ
#
#  SPACE
# departed VERB
# . PUNCT
#   SPACE
# Every DET
# day NOUN
# the DET
# maiden NOUN
# went VERB
# out ADP
# ...

# %%
#NER
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Cinderella PERSON
# winter DATE
# two CARDINAL
# morning TIME
# night TIME
# the evening TIME
# two CARDINAL
# one CARDINAL
# second ORDINAL
# first ORDINAL
# two CARDINAL
# hazel-bush PERSON
# Cinderella PERSON
# cinderella PERSON
# last three days DATE
# two CARDINAL
# Cinderella PERSON
# two hours TIME
# two CARDINAL
# one hour TIME
# two CARDINAL
# one hour TIME
# two CARDINAL
# two CARDINAL
# half an
# hour TIME
# two CARDINAL
# one CARDINAL
# evening TIME
# the mantle-piece EVENT
# cinderella PERSON
# Next day DATE
# the preceding day DATE
# evening TIME
# Therein FAC
# the third day DATE
# evening TIME
# cinderella PERSON
# Next morning TIME
# two CARDINAL
# two CARDINAL
# two CARDINAL
# first ORDINAL
# two CARDINAL
# two CARDINAL
# two CARDINAL
# one CARDINAL
# two CARDINAL
# one CARDINAL
# all their days DATE

# %%
#frequency NER
entity=[]
from collections import Counter
labels=[x.label_ for x in doc.ents]
Counter(labels)
#entity.append()
# Out:
# Counter({'PERSON': 7,
#          'DATE': 6,
#          'CARDINAL': 20,
#          'TIME': 11,
#          'ORDINAL': 3,
#          'EVENT': 1,
#          'FAC': 1})

# %%
from spacy import displacy
displacy.serve(doc, style="ent")
# Out:
# C:\Users\riyag\Anaconda3\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...
